# %%
import kagglehub
import os

print(kagglehub)
os.environ["KAGGLE_API_TOKEN"] = "KGAT_c9fe30746e01f511b5f64fcce9096d9b"
kagglehub.login()
# Out:
# <module 'kagglehub' from 'c:\\Users\\user\\Desktop\\311-thesisproj\\311_Env\\Lib\\site-packages\\kagglehub\\__init__.py'>
# ...

# %%
path = kagglehub.competition_download('open-images-object-detection-rvc-2020')

print("Path to competition files:", path)
# Out:
# ...
# 100%|██████████| 9.69G/9.69G [09:42<00:00, 17.9MB/s]
# Extracting files...
# Path to competition files: C:\Users\user\.cache\kagglehub\competitions\open-images-object-detection-rvc-2020
